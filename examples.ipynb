# %%
# Plot Chart Example:
from matplotlib import pyplot as plt

# Axes: y is assumed if only 1 list is given.
plt.plot(['Item 1', 'Item 2', 'Item 3', 'Item 4'], [10, 13, 20, 30])
# Scale for x-axis and y-axis, respectively
plt.axis([0, 4, 0, 40])
plt.ylabel('Counts')

plt.show()

# %%
from examples import *

accounts, all_transactions_total = utils_example()

print('Initalized and ready.')
# Out:
# Initalized and ready.

# %%
# Plotting a basic bar graph
plt.bar(accounts, all_transactions_total)
plt.xlabel('Accounts')
plt.ylabel('Transaction Amount')
plt.title('Comparison: All Transactions')
plt.show()

# %% [markdown]
# # Fraud Investigation Report
#
# Your report findings should go here.
